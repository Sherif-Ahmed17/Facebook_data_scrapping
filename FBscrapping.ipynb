# %%
import json

# %%
with open('E:\\finalfbscrapping\\Testing.json', encoding="utf8") as f:
  data = json.load(f)

# %%
import pandas as pd
df = pd.DataFrame(columns=["post_id", "post", "likes", "comments", "author", "isVerified", "dateNow"])

# %%
for i in range (0, len(data)):
    currentItem = data[i]
    df.loc[i] = [data[i]["post_id"], data[i]["post"], data[i]["likes"], data[i]["comments"], data[i]["author"], data[i]["isVerified"], data[i]["dateNow"]]

# %%
df
# Out:
#   post_id                                               post likes comments  \
# 0       1  الاكل الاميريكان الي بجد حاضر في القاهره و باح...    86      43
# 1       2  ملوك برطمانات الجبنة السايحة و البرجر العالمي ...     2
# 2       3  هارت اتاك هيوزعوا 2 طن فرايد تشيكن هدية فى فرع...    35
# 3       4  هتلاقيهم بيوزعوا  كريب شوكلاتة ببلاش علي أي كر...   177      62
# 4       5  هنا هتقدر تاكل اكلة سي فوود محترمة و بأحلي الا...   155      35
# 5       6  عمركوا فكرتوا قبل كدة إن الشاورما ممكن تبقى أك...    43
# 6       7  اجمد و اطعم فرايد تشيكن و برجر و حاجات تانية ك...   135      32
# 7       8  ملوك  الاكل العربي و الغربي كمان مكسرين الدنيا...   284      29
# 8       9  جهز نفسك لـ 1OOO وجبة بيك ببلاش هتلاقيهم مستني...    79      98
# 9      10  عيد ميلاد بنده بدأ كله مفاجأت و توفير وهدايا ك...    79
#
#           author isVerified             dateNow
# 0  Kersh Keepers      False  2021-9-20 21:59:33
# 1  Kersh Keepers      False  2021-9-20 21:59:35
# ...
